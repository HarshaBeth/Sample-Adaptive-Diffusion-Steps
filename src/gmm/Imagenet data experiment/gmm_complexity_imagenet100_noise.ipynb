# %%
import joblib

gmm = joblib.load("./checkpoints/gmm_100_500iter_reg1-5/gmm_100_diag_reg1e-5.pkl")
scaler = joblib.load("./checkpoints/gmm_100_500iter_reg1-5/patch_scaler.pkl")

# %%
print("Components:", gmm.n_components)
# Out:
# Components: 100

# %%
from pathlib import Path

PROJECT_ROOT = Path("/path/Sample-Adaptive-Diffusion-Steps")

DDR_ROOT = PROJECT_ROOT / "external" / "ddrm"
REF_RUN_DIR = DDR_ROOT / "exp" / "image_samples" / "IMAGENET 100 IMAGES NOISE" / "run_k50_100imgs"

eval_image_paths = sorted(list(REF_RUN_DIR.glob("y0_*.png")))

print("num eval degraded images:", len(eval_image_paths))
for p in eval_image_paths:
    print(p.name)
# Out:
# num eval degraded images: 100
# y0_0.png
# y0_1.png
# y0_10.png
# y0_11.png
# y0_12.png
# y0_13.png
# y0_14.png
# y0_15.png
# y0_16.png
# y0_17.png
# y0_18.png
# y0_19.png
# y0_2.png
# y0_20.png
# y0_21.png
# y0_22.png
# y0_23.png
# y0_24.png
# y0_25.png
# y0_26.png
# y0_27.png
# y0_28.png
# y0_29.png
# y0_3.png
# y0_30.png
# y0_31.png
# y0_32.png
# y0_33.png
# y0_34.png
# y0_35.png
# y0_36.png
# y0_37.png
# y0_38.png
# y0_39.png
# y0_4.png
# y0_40.png
# y0_41.png
# y0_42.png
# y0_43.png
# y0_44.png
# y0_45.png
# y0_46.png
# y0_47.png
# y0_48.png
# y0_49.png
# y0_5.png
# y0_50.png
# y0_51.png
# y0_52.png
# y0_53.png
# y0_54.png
# y0_55.png
# y0_56.png
# y0_57.png
# y0_58.png
# y0_59.png
# y0_6.png
# y0_60.png
# y0_61.png
# y0_62.png
# y0_63.png
# y0_64.png
# y0_65.png
# y0_66.png
# y0_67.png
# y0_68.png
# y0_69.png
# y0_7.png
# y0_70.png
# y0_71.png
# y0_72.png
# y0_73.png
# y0_74.png
# y0_75.png
# y0_76.png
# y0_77.png
# y0_78.png
# y0_79.png
# y0_8.png
# y0_80.png
# y0_81.png
# y0_82.png
# y0_83.png
# y0_84.png
# y0_85.png
# y0_86.png
# y0_87.png
# y0_88.png
# y0_89.png
# y0_9.png
# y0_90.png
# y0_91.png
# y0_92.png
# y0_93.png
# y0_94.png
# y0_95.png
# y0_96.png
# y0_97.png
# y0_98.png
# y0_99.png

# %%
kstar_labels = {
    "orig_0.png": 27,
    "orig_1.png": 45,
    "orig_2.png": 8,
    "orig_3.png": 87,
    "orig_4.png": 75,
    "orig_5.png": 15,
    "orig_6.png": 100,
    "orig_7.png": 50,
    "orig_8.png": 45,
    "orig_9.png": 35,
    "orig_10.png": 35,
    "orig_11.png": 62,
    "orig_12.png": 8,
    "orig_13.png": 22,
    "orig_14.png": 35,
    "orig_15.png": 100,
    "orig_16.png": 62,
    "orig_17.png": 62,
    "orig_18.png": 22,
    "orig_19.png": 22,
    "orig_20.png": 75,
    "orig_21.png": 27,
    "orig_22.png": 20,
    "orig_23.png": 7,
    "orig_24.png": 15,
    "orig_25.png": 5,
    "orig_26.png": 62,
    "orig_27.png": 75,
    "orig_28.png": 62,
    "orig_29.png": 87,
    "orig_30.png": 8,
    "orig_31.png": 12,
    "orig_32.png": 87,
    "orig_33.png": 100,
    "orig_34.png": 62,
    "orig_35.png": 17,
    "orig_36.png": 15,
    "orig_37.png": 7,
    "orig_38.png": 27,
    "orig_39.png": 87,
    "orig_40.png": 62,
    "orig_41.png": 40,
    "orig_42.png": 50,
    "orig_43.png": 62,
    "orig_44.png": 35,
    "orig_45.png": 6,
    "orig_46.png": 27,
    "orig_47.png": 35,
    "orig_48.png": 62,
    "orig_49.png": 75,
    "orig_50.png": 15,
    "orig_51.png": 62,
    "orig_52.png": 10,
    "orig_53.png": 62,
    "orig_54.png": 75,
    "orig_55.png": 10,
    "orig_56.png": 22,
    "orig_57.png": 40,
    "orig_58.png": 75,
    "orig_59.png": 17,
    "orig_60.png": 10,
    "orig_61.png": 20,
    "orig_62.png": 22,
    "orig_63.png": 15,
    "orig_64.png": 27,
    "orig_65.png": 45,
    "orig_66.png": 20,
    "orig_67.png": 75,
    "orig_68.png": 30,
    "orig_69.png": 5,
    "orig_70.png": 30,
    "orig_71.png": 75,
    "orig_72.png": 40,
    "orig_73.png": 12,
    "orig_74.png": 62,
    "orig_75.png": 27,
    "orig_76.png": 100,
    "orig_77.png": 15,
    "orig_78.png": 87,
    "orig_79.png": 40,
    "orig_80.png": 62,
    "orig_81.png": 75,
    "orig_82.png": 12,
    "orig_83.png": 50,
    "orig_84.png": 75,
    "orig_85.png": 87,
    "orig_86.png": 35,
    "orig_87.png": 25,
    "orig_88.png": 75,
    "orig_89.png": 62,
    "orig_90.png": 50,
    "orig_91.png": 15,
    "orig_92.png": 87,
    "orig_93.png": 17,
    "orig_94.png": 45,
    "orig_95.png": 75,
    "orig_96.png": 100,
    "orig_97.png": 12,
    "orig_98.png": 25,
    "orig_99.png": 75,
}

# %%
def load_grayscale_image(path, image_size=64):
    img = Image.open(path).convert("L")  # grayscale
    img = img.resize((image_size, image_size))
    arr = np.array(img).astype(np.float32) / 255.0
    return arr

def extract_patches(img, patch_size=8, stride=4):
    patches = []
    H, W = img.shape
    for i in range(0, H - patch_size + 1, stride):
        for j in range(0, W - patch_size + 1, stride):
            patch = img[i:i+patch_size, j:j+patch_size].reshape(-1)
            patches.append(patch)
    return np.array(patches, dtype=np.float32)

# %%
def image_complexity_nll(path, image_size=64, patch_size=8, stride=4):
    img = load_grayscale_image(path, image_size=image_size)
    patches = extract_patches(img, patch_size=patch_size, stride=stride)
    patches_scaled = scaler.transform(patches)

    log_probs = gmm.score_samples(patches_scaled)
    nll = -log_probs

    top_k = max(1, int(0.1 * len(nll)))
    sorted_nll = np.sort(nll)

    return {
        "mean_nll": float(np.mean(nll)),
        "std_nll": float(np.std(nll)),
        "max_nll": float(np.max(nll)),
        "median_nll": float(np.median(nll)),
        "p90_nll": float(np.percentile(nll, 90)),
        "top10_mean_nll": float(np.mean(sorted_nll[-top_k:])),
    }

# %%
import re
from PIL import Image
import numpy as np

def extract_image_idx(filename):
    # works for y0_0.png, orig_3.png, etc.
    m = re.search(r"_(\d+)\.png$", filename)
    if m is None:
        raise ValueError(f"Could not extract image index from {filename}")
    return int(m.group(1))

rows = []

for path in eval_image_paths:
    idx = extract_image_idx(path.name)
    orig_name = f"orig_{idx}.png"   # maps degraded image back to your k* labels

    stats = image_complexity_nll(path, image_size=64, patch_size=8, stride=4)

    rows.append({
        "image": path.name,          # now this will be y0_*.png
        "image_idx": idx,
        "mean_nll": stats["mean_nll"],
        "std_nll": stats["std_nll"],
        "max_nll": stats["max_nll"],
        "median_nll": stats["median_nll"],
        "p90_nll": stats["p90_nll"],
        "top10_mean_nll": stats["top10_mean_nll"],
        "kstar": kstar_labels[orig_name],
    })

rows
# Out:
# [{'image': 'y0_0.png',
#   'image_idx': 0,
#   'mean_nll': -39.746578412466825,
#   'std_nll': 32.33827454798502,
#   'max_nll': 38.19919873983809,
#   'median_nll': -38.45336956481801,
#   'p90_nll': 1.8467860978978883,
#   'top10_mean_nll': 15.730550210763715,
#   'kstar': 27},
#  {'image': 'y0_1.png',
#   'image_idx': 1,
#   'mean_nll': -6.047211184708958,
#   'std_nll': 35.58833506204855,
#   'max_nll': 50.648747974312,
#   'median_nll': -1.5652272772330411,
#   'p90_nll': 38.556590680834354,
#   'top10_mean_nll': 44.692743326235664,
#   'kstar': 45},
#  {'image': 'y0_10.png',
#   'image_idx': 10,
#   'mean_nll': -12.75132782932116,
#   'std_nll': 24.40311627062297,
#   'max_nll': 60.45530616260083,
#   'median_nll': -14.614784581392737,
#   'p90_nll': 16.5578064102949,
#   'top10_mean_nll': 36.09797706252697,
#   'kstar': 35},
#  {'image': 'y0_11.png',
#   'image_idx': 11,
#   'mean_nll': -1.2676305953640663,
#   'std_nll': 24.833925774973462,
#   'max_nll': 48.90189641173528,
#   'median_nll': 3.4314265395362473,
#   'p90_nll': 24.105336637321287,
#   'top10_mean_nll': 33.21222723290876,
#   'kstar': 62},
#  {'image': 'y0_12.png',
#   'image_idx': 12,
#   'mean_nll': 2.498776332451984,
#   'std_nll': 25.283477173285327,
#   'max_nll': 50.786066253305805,
#   'median_nll': 4.420962568451909,
#   'p90_nll': 33.879754609720585,
#   'top10_mean_nll': 41.13184635411291,
#   'kstar': 8},
#  {'image': 'y0_13.png',
#   'image_idx': 13,
#   'mean_nll': -13.54618169486323,
#   'std_nll': 40.221934023688284,
#   'max_nll': 58.35990520446422,
#   'median_nll': -6.75113683673903,
#   'p90_nll': 38.121467309437485,
#   'top10_mean_nll': 45.69191590343552,
#   'kstar': 22},
#  {'image': 'y0_14.png',
#   'image_idx': 14,
#   'mean_nll': -10.200827133748968,
#   'std_nll': 34.3474126894375,
#   'max_nll': 56.725045834346155,
#   'median_nll': -3.2156080427287805,
#   'p90_nll': 29.086692527427665,
#   'top10_mean_nll': 38.127761395103306,
#   'kstar': 35},
#  {'image': 'y0_15.png',
#   'image_idx': 15,
#   'mean_nll': 18.345125315789975,
#   'std_nll': 13.501345645884877,
#   'max_nll': 47.883068773427794,
#   'median_nll': 21.139816415104672,
#   'p90_nll': 32.79699884575272,
#   'top10_mean_nll': 37.58323640791954,
#   'kstar': 100},
#  {'image': 'y0_16.png',
#   'image_idx': 16,
#   'mean_nll': -8.368402432589882,
#   'std_nll': 41.15131168885381,
#   'max_nll': 82.29285054224613,
#   'median_nll': -1.383241289467973,
#   'p90_nll': 46.51808703463652,
#   'top10_mean_nll': 57.55448351272034,
#   'kstar': 62},
#  {'image': 'y0_17.png',
#   'image_idx': 17,
#   'mean_nll': -10.157573163439443,
#   'std_nll': 31.31896677033998,
#   'max_nll': 48.80844575703804,
#   'median_nll': -8.084821504853258,
#   'p90_nll': 30.332667981271953,
#   'top10_mean_nll': 36.41566151226824,
#   'kstar': 62},
#  {'image': 'y0_18.png',
#   'image_idx': 18,
#   'mean_nll': -40.73990531389462,
#   'std_nll': 35.82564931020782,
#   'max_nll': 43.91020294828455,
#   'median_nll': -51.694770144281094,
#   'p90_nll': 9.972613392582971,
#   'top10_mean_nll': 18.777923455469395,
#   'kstar': 22},
#  {'image': 'y0_19.png',
#   'image_idx': 19,
#   'mean_nll': -39.14435928439574,
#   'std_nll': 38.359718855608925,
#   'max_nll': 44.20547043893411,
#   'median_nll': -50.63571272553848,
#   'p90_nll': 15.756011602283237,
#   'top10_mean_nll': 25.133742118430295,
#   'kstar': 22},
#  {'image': 'y0_2.png',
#   'image_idx': 2,
#   'mean_nll': -14.86344205459761,
#   'std_nll': 22.97031013061123,
#   'max_nll': 27.681100215887465,
#   'median_nll': -14.561051106387108,
#   'p90_nll': 13.8287520404713,
#   'top10_mean_nll': 19.79266757652995,
#   'kstar': 8},
#  {'image': 'y0_20.png',
#   'image_idx': 20,
#   'mean_nll': 4.584249845469081,
#   'std_nll': 37.92058999714186,
#   'max_nll': 64.37260906919397,
#   'median_nll': 19.239674051253473,
#   'p90_nll': 42.589253107741435,
#   'top10_mean_nll': 48.86191495805994,
#   'kstar': 75},
#  {'image': 'y0_21.png',
#   'image_idx': 21,
#   'mean_nll': 0.5767586240967284,
#   'std_nll': 29.54236348136843,
#   'max_nll': 58.690098730361264,
#   'median_nll': 5.664059269306919,
#   'p90_nll': 36.8603692757327,
#   'top10_mean_nll': 43.660776539597386,
#   'kstar': 27},
#  {'image': 'y0_22.png',
#   'image_idx': 22,
#   'mean_nll': -20.92820694863273,
#   'std_nll': 36.64079098254608,
#   'max_nll': 62.120654118978884,
#   'median_nll': -17.432540002481538,
#   'p90_nll': 23.666580972491673,
#   'top10_mean_nll': 34.67751518440511,
#   'kstar': 20},
#  {'image': 'y0_23.png',
#   'image_idx': 23,
#   'mean_nll': -4.32565255909983,
#   'std_nll': 31.602549551661788,
#   'max_nll': 63.495850987639294,
#   'median_nll': -6.964441791164345,
#   'p90_nll': 36.76786423396021,
#   'top10_mean_nll': 47.60191106707252,
#   'kstar': 7},
#  {'image': 'y0_24.png',
#   'image_idx': 24,
#   'mean_nll': -44.5599013862771,
#   'std_nll': 24.83759521363361,
#   'max_nll': 27.82178157590465,
#   'median_nll': -52.47374742691372,
#   'p90_nll': -7.047179810309979,
#   'top10_mean_nll': 8.67717893363499,
#   'kstar': 15},
#  {'image': 'y0_25.png',
#   'image_idx': 25,
#   'mean_nll': -29.0784748899104,
#   'std_nll': 24.248822458503444,
#   'max_nll': 17.212535722601494,
#   'median_nll': -20.035035956431738,
#   'p90_nll': -1.9449672744632975,
#   'top10_mean_nll': 6.5993473715137325,
#   'kstar': 5},
#  {'image': 'y0_26.png',
#   'image_idx': 26,
#   'mean_nll': -4.995028638955819,
#   'std_nll': 35.044221424926256,
#   'max_nll': 61.41167345837091,
#   'median_nll': -3.789346277259571,
#   'p90_nll': 40.8562476832073,
#   'top10_mean_nll': 49.92166151467175,
#   'kstar': 62},
#  {'image': 'y0_27.png',
#   'image_idx': 27,
#   'mean_nll': -10.875598224965547,
#   'std_nll': 32.02441089598609,
#   'max_nll': 42.799217037538675,
#   'median_nll': -4.4778361260720905,
#   'p90_nll': 26.729280058396505,
#   'top10_mean_nll': 32.97254837852328,
#   'kstar': 75},
#  {'image': 'y0_28.png',
#   'image_idx': 28,
#   'mean_nll': -6.069148328160342,
#   'std_nll': 19.882049538251227,
#   'max_nll': 37.31606034290667,
#   'median_nll': -7.438869922871215,
#   'p90_nll': 20.583377922986475,
#   'top10_mean_nll': 27.23402472958687,
#   'kstar': 62},
#  {'image': 'y0_29.png',
#   'image_idx': 29,
#   'mean_nll': 3.8982586819508733,
#   'std_nll': 21.772825185254813,
#   'max_nll': 40.71702880619081,
#   'median_nll': 7.810868111712139,
#   'p90_nll': 28.894910981602465,
#   'top10_mean_nll': 33.382888723426916,
#   'kstar': 87},
#  {'image': 'y0_3.png',
#   'image_idx': 3,
#   'mean_nll': -2.7672828402354632,
#   'std_nll': 30.39783353065564,
#   'max_nll': 52.14659437592839,
#   'median_nll': 6.525556350157235,
#   'p90_nll': 27.81141600242025,
#   'top10_mean_nll': 36.80249725429118,
#   'kstar': 87},
#  {'image': 'y0_30.png',
#   'image_idx': 30,
#   'mean_nll': -12.343980454798986,
#   'std_nll': 31.64706124163808,
#   'max_nll': 51.09568355854647,
#   'median_nll': -9.077795127200153,
#   'p90_nll': 26.197975509157413,
#   'top10_mean_nll': 34.783327955208335,
#   'kstar': 8},
#  {'image': 'y0_31.png',
#   'image_idx': 31,
#   'mean_nll': -5.006145666275307,
#   'std_nll': 27.90996650609296,
#   'max_nll': 42.96680236488385,
#   'median_nll': 1.7934570702918302,
#   'p90_nll': 25.597101344167367,
#   'top10_mean_nll': 32.121536782297774,
#   'kstar': 12},
#  {'image': 'y0_32.png',
#   'image_idx': 32,
#   'mean_nll': 16.451055148137446,
#   'std_nll': 19.979864658207358,
#   'max_nll': 49.09046077537727,
#   'median_nll': 20.971520144185565,
#   'p90_nll': 35.41048467561904,
#   'top10_mean_nll': 40.20779669062234,
#   'kstar': 87},
#  {'image': 'y0_33.png',
#   'image_idx': 33,
#   'mean_nll': -27.92467433142145,
#   'std_nll': 37.04249615098596,
#   'max_nll': 30.71518317187278,
#   'median_nll': -14.85075556306913,
#   'p90_nll': 14.873445142497237,
#   'top10_mean_nll': 20.747964405393986,
#   'kstar': 100},
#  {'image': 'y0_34.png',
#   'image_idx': 34,
#   'mean_nll': -2.0823025689538723,
#   'std_nll': 41.04291574439431,
#   'max_nll': 79.90396879207997,
#   'median_nll': 4.605691433878859,
#   'p90_nll': 46.254430398631875,
#   'top10_mean_nll': 61.396925726944204,
#   'kstar': 62},
#  {'image': 'y0_35.png',
#   'image_idx': 35,
#   'mean_nll': -6.180159225918221,
#   'std_nll': 27.03023740958788,
#   'max_nll': 44.437006611182426,
#   'median_nll': -2.389334343087153,
#   'p90_nll': 22.614002406055466,
#   'top10_mean_nll': 28.426165647801326,
#   'kstar': 17},
#  {'image': 'y0_36.png',
#   'image_idx': 36,
#   'mean_nll': -7.798735751357726,
#   'std_nll': 39.2118083363971,
#   'max_nll': 68.52116000677952,
#   'median_nll': -1.128213307835144,
#   'p90_nll': 42.806957470564846,
#   'top10_mean_nll': 52.28506650576021,
#   'kstar': 15},
#  {'image': 'y0_37.png',
#   'image_idx': 37,
#   'mean_nll': -28.799038649545608,
#   'std_nll': 29.761085456605247,
#   'max_nll': 21.45134480149311,
#   'median_nll': -29.765874250806377,
#   'p90_nll': 14.824939793325164,
#   'top10_mean_nll': 18.05141650925267,
#   'kstar': 7},
#  {'image': 'y0_38.png',
#   'image_idx': 38,
#   'mean_nll': 0.9722061348647296,
#   'std_nll': 31.4938146946556,
#   'max_nll': 72.39855311651344,
#   'median_nll': 5.63031271100011,
#   'p90_nll': 33.677280929450504,
#   'top10_mean_nll': 49.89172840296423,
#   'kstar': 27},
#  {'image': 'y0_39.png',
#   'image_idx': 39,
#   'mean_nll': -13.003265208520574,
#   'std_nll': 35.45851394946372,
#   'max_nll': 44.23247158768849,
#   'median_nll': -9.713685074374776,
#   'p90_nll': 27.58263633317862,
#   'top10_mean_nll': 33.54085817688369,
#   'kstar': 87},
#  {'image': 'y0_4.png',
#   'image_idx': 4,
#   'mean_nll': -20.066619400561496,
#   'std_nll': 28.18431326842141,
#   'max_nll': 31.27179028985469,
#   'median_nll': -17.283175978196464,
#   'p90_nll': 15.383014040604964,
#   'top10_mean_nll': 20.688712962483947,
#   'kstar': 75},
#  {'image': 'y0_40.png',
#   'image_idx': 40,
#   'mean_nll': 27.556564232300005,
#   'std_nll': 23.429686497014725,
#   'max_nll': 65.1290443002874,
#   'median_nll': 31.98337783275117,
#   'p90_nll': 46.9654014690991,
#   'top10_mean_nll': 54.45285034923922,
#   'kstar': 62},
#  {'image': 'y0_41.png',
#   'image_idx': 41,
#   'mean_nll': 0.6323331668509391,
#   'std_nll': 24.708476838727663,
#   'max_nll': 60.03595433882358,
#   'median_nll': 1.0450536237259545,
#   'p90_nll': 29.678702479194072,
#   'top10_mean_nll': 43.606352965982005,
#   'kstar': 40},
#  {'image': 'y0_42.png',
#   'image_idx': 42,
#   'mean_nll': -3.689067580858579,
#   'std_nll': 31.092380424623126,
#   'max_nll': 81.68759805748249,
#   'median_nll': 2.9769072113047983,
#   'p90_nll': 27.466409629085657,
#   'top10_mean_nll': 44.119186282287885,
#   'kstar': 50},
#  {'image': 'y0_43.png',
#   'image_idx': 43,
#   'mean_nll': 7.975687594603796,
#   'std_nll': 25.821782280488684,
#   'max_nll': 63.62790924455626,
#   'median_nll': 12.007154702108345,
#   'p90_nll': 36.73975901172747,
#   'top10_mean_nll': 46.168177781192725,
#   'kstar': 62},
#  {'image': 'y0_44.png',
#   'image_idx': 44,
#   'mean_nll': -11.127790602690713,
#   'std_nll': 39.29060609871772,
#   'max_nll': 46.214042806317664,
#   'median_nll': 3.9683777702026695,
#   'p90_nll': 26.99400870723204,
#   'top10_mean_nll': 33.42430054808996,
#   'kstar': 35},
#  {'image': 'y0_45.png',
#   'image_idx': 45,
#   'mean_nll': -24.72345257945653,
#   'std_nll': 42.973858526004186,
#   'max_nll': 57.62767999990583,
#   'median_nll': -12.970121732174997,
#   'p90_nll': 25.074835366357522,
#   'top10_mean_nll': 34.290487085118244,
#   'kstar': 6},
#  {'image': 'y0_46.png',
#   'image_idx': 46,
#   'mean_nll': -28.002856308317103,
#   'std_nll': 39.66403062118985,
#   'max_nll': 45.219317134939985,
#   'median_nll': -19.772466682321433,
#   'p90_nll': 24.503139395554054,
#   'top10_mean_nll': 33.81936174706637,
#   'kstar': 27},
#  {'image': 'y0_47.png',
#   'image_idx': 47,
#   'mean_nll': -21.911214560465055,
#   'std_nll': 40.68771067205636,
#   'max_nll': 54.30158375016049,
#   'median_nll': -15.862907896505657,
#   'p90_nll': 28.299549544850034,
#   'top10_mean_nll': 37.26411497372505,
#   'kstar': 35},
#  {'image': 'y0_48.png',
#   'image_idx': 48,
#   'mean_nll': -5.744631920899261,
#   'std_nll': 34.985991378095946,
#   'max_nll': 70.61686426962906,
#   'median_nll': 0.2666853651534665,
#   'p90_nll': 35.30858088147697,
#   'top10_mean_nll': 49.91349242404102,
#   'kstar': 62},
#  {'image': 'y0_49.png',
#   'image_idx': 49,
#   'mean_nll': -12.835505206162242,
#   'std_nll': 36.29541688961036,
#   'max_nll': 40.44591431918929,
#   'median_nll': -3.3714771837831417,
#   'p90_nll': 27.820624007261028,
#   'top10_mean_nll': 33.81730356564859,
#   'kstar': 75},
#  {'image': 'y0_5.png',
#   'image_idx': 5,
#   'mean_nll': -13.854368554953766,
#   'std_nll': 42.24403944966495,
#   'max_nll': 55.16887629100231,
#   'median_nll': -0.9051286072935169,
#   'p90_nll': 36.890865544206385,
#   'top10_mean_nll': 42.863662312849065,
#   'kstar': 15},
#  {'image': 'y0_50.png',
#   'image_idx': 50,
#   'mean_nll': -0.6291236399168753,
#   'std_nll': 25.687254872037776,
#   'max_nll': 55.4692677243312,
#   'median_nll': -0.1379019461812012,
#   'p90_nll': 29.954946108761636,
#   'top10_mean_nll': 39.61199469564607,
#   'kstar': 15},
#  {'image': 'y0_51.png',
#   'image_idx': 51,
#   'mean_nll': -16.516332235513847,
#   'std_nll': 37.4169971421234,
#   'max_nll': 46.96469291573002,
#   'median_nll': -4.998868099877936,
#   'p90_nll': 28.842225704930467,
#   'top10_mean_nll': 34.38474394308052,
#   'kstar': 62},
#  {'image': 'y0_52.png',
#   'image_idx': 52,
#   'mean_nll': -21.55510285773603,
#   'std_nll': 30.633428084456646,
#   'max_nll': 48.76119039205515,
#   'median_nll': -23.36446760368104,
#   'p90_nll': 18.722391334283557,
#   'top10_mean_nll': 30.968928056321086,
#   'kstar': 10},
#  {'image': 'y0_53.png',
#   'image_idx': 53,
#   'mean_nll': 2.8496915800659597,
#   'std_nll': 27.94963787037721,
#   'max_nll': 59.35297236138824,
#   'median_nll': 7.983228943520153,
#   'p90_nll': 34.84712455870164,
#   'top10_mean_nll': 45.00754857877307,
#   'kstar': 62},
#  {'image': 'y0_54.png',
#   'image_idx': 54,
#   'mean_nll': -6.668199771564404,
#   'std_nll': 29.386089690674773,
#   'max_nll': 50.61224311387155,
#   'median_nll': -0.780947550352021,
#   'p90_nll': 24.449596110680464,
#   'top10_mean_nll': 35.87627613919572,
#   'kstar': 75},
#  {'image': 'y0_55.png',
#   'image_idx': 55,
#   'mean_nll': -2.4869457432416655,
#   'std_nll': 28.97756623665936,
#   'max_nll': 56.03454617510104,
#   'median_nll': 0.011915568635921284,
#   'p90_nll': 30.55121125874364,
#   'top10_mean_nll': 40.190607188713805,
#   'kstar': 10},
#  {'image': 'y0_56.png',
#   'image_idx': 56,
#   'mean_nll': -36.45860981498873,
#   'std_nll': 35.8936400978993,
#   'max_nll': 41.32017406720598,
#   'median_nll': -46.432019289361804,
#   'p90_nll': 17.195448971889743,
#   'top10_mean_nll': 27.10152862034123,
#   'kstar': 22},
#  {'image': 'y0_57.png',
#   'image_idx': 57,
#   'mean_nll': -18.566136819692474,
#   'std_nll': 34.69036861279416,
#   'max_nll': 38.75489038589738,
#   'median_nll': -12.814001727844921,
#   'p90_nll': 20.640097784605068,
#   'top10_mean_nll': 28.96695388761593,
#   'kstar': 40},
#  {'image': 'y0_58.png',
#   'image_idx': 58,
#   'mean_nll': -8.113997535368764,
#   'std_nll': 32.47772167683129,
#   'max_nll': 69.75565617549748,
#   'median_nll': -6.886727241311701,
#   'p90_nll': 33.00935997878823,
#   'top10_mean_nll': 46.50690110521576,
#   'kstar': 75},
#  {'image': 'y0_59.png',
#   'image_idx': 59,
#   'mean_nll': -51.813029925346896,
#   'std_nll': 36.91365878354089,
#   'max_nll': 37.21099845453329,
#   'median_nll': -65.62519422710854,
#   'p90_nll': 12.887804701128978,
#   'top10_mean_nll': 21.555061359660286,
#   'kstar': 17},
#  {'image': 'y0_6.png',
#   'image_idx': 6,
#   'mean_nll': -47.533971083788245,
#   'std_nll': 40.06714705577627,
#   'max_nll': 36.28790636484131,
#   'median_nll': -69.52396687303188,
#   'p90_nll': 14.664917763891498,
#   'top10_mean_nll': 21.604861755853292,
#   'kstar': 100},
#  {'image': 'y0_60.png',
#   'image_idx': 60,
#   'mean_nll': -6.344250538516457,
#   'std_nll': 41.809614462322315,
#   'max_nll': 53.95150088851486,
#   'median_nll': 11.831498989893237,
#   'p90_nll': 38.8020693761613,
#   'top10_mean_nll': 46.18943558742545,
#   'kstar': 10},
#  {'image': 'y0_61.png',
#   'image_idx': 61,
#   'mean_nll': -33.52219588198872,
#   'std_nll': 37.749960638908476,
#   'max_nll': 45.022276342719515,
#   'median_nll': -43.28152976169918,
#   'p90_nll': 14.575117898186994,
#   'top10_mean_nll': 27.172300488691288,
#   'kstar': 20},
#  {'image': 'y0_62.png',
#   'image_idx': 62,
#   'mean_nll': -29.54138334572597,
#   'std_nll': 35.7319591765321,
#   'max_nll': 38.13999620335252,
#   'median_nll': -28.551524780138454,
#   'p90_nll': 19.51032683968039,
#   'top10_mean_nll': 28.272051254712725,
#   'kstar': 22},
#  {'image': 'y0_63.png',
#   'image_idx': 63,
#   'mean_nll': -19.356141126933412,
#   'std_nll': 39.61328074450936,
#   'max_nll': 55.00425452630818,
#   'median_nll': -27.83149413065778,
#   'p90_nll': 38.86220353550089,
#   'top10_mean_nll': 46.61268189936314,
#   'kstar': 15},
#  {'image': 'y0_64.png',
#   'image_idx': 64,
#   'mean_nll': 7.322644876593358,
#   'std_nll': 27.481093646475426,
#   'max_nll': 53.88325194289604,
#   'median_nll': 13.425201840290137,
#   'p90_nll': 33.93202364995721,
#   'top10_mean_nll': 41.30066431944405,
#   'kstar': 27},
#  {'image': 'y0_65.png',
#   'image_idx': 65,
#   'mean_nll': 13.241510815040641,
#   'std_nll': 26.852637774301474,
#   'max_nll': 66.85916571115695,
#   'median_nll': 16.46856046135302,
#   'p90_nll': 44.61954653418935,
#   'top10_mean_nll': 52.93946455194682,
#   'kstar': 45},
#  {'image': 'y0_66.png',
#   'image_idx': 66,
#   'mean_nll': -16.631803025854015,
#   'std_nll': 32.703167199801186,
#   'max_nll': 40.58980364784826,
#   'median_nll': -12.091489581534335,
#   'p90_nll': 21.51213347715212,
#   'top10_mean_nll': 29.426508664037122,
#   'kstar': 20},
#  {'image': 'y0_67.png',
#   'image_idx': 67,
#   'mean_nll': -34.01968603021498,
#   'std_nll': 38.22018232927997,
#   'max_nll': 43.95429319235543,
#   'median_nll': -32.99375487937286,
#   'p90_nll': 16.26440873597978,
#   'top10_mean_nll': 26.547281673460734,
#   'kstar': 75},
#  {'image': 'y0_68.png',
#   'image_idx': 68,
#   'mean_nll': -4.498297337053744,
#   'std_nll': 22.659180225586002,
#   'max_nll': 43.123321850433435,
#   'median_nll': -7.054454335489421,
#   'p90_nll': 25.734681577735223,
#   'top10_mean_nll': 32.01698948430147,
#   'kstar': 30},
#  {'image': 'y0_69.png',
#   'image_idx': 69,
#   'mean_nll': -40.26785722993565,
#   'std_nll': 24.87761383814566,
#   'max_nll': 33.83577206607645,
#   'median_nll': -45.01532447994057,
#   'p90_nll': -9.35686435480153,
#   'top10_mean_nll': 3.2689556299990077,
#   'kstar': 5},
#  {'image': 'y0_7.png',
#   'image_idx': 7,
#   'mean_nll': -3.1541105553261164,
#   'std_nll': 24.469044890152695,
#   'max_nll': 63.18712134630886,
#   'median_nll': -2.818179094510839,
#   'p90_nll': 26.938343624268867,
#   'top10_mean_nll': 36.11147912846736,
#   'kstar': 50},
#  {'image': 'y0_70.png',
#   'image_idx': 70,
#   'mean_nll': -5.922126327323814,
#   'std_nll': 15.387825564874683,
#   'max_nll': 30.994100896890902,
#   'median_nll': -5.494938551984489,
#   'p90_nll': 13.187795709538396,
#   'top10_mean_nll': 19.711809448100414,
#   'kstar': 30},
#  {'image': 'y0_71.png',
#   'image_idx': 71,
#   'mean_nll': 15.693575740726628,
#   'std_nll': 23.552989600776524,
#   'max_nll': 57.697365416707214,
#   'median_nll': 20.748632844827718,
#   'p90_nll': 39.860233802564494,
#   'top10_mean_nll': 45.811174485002496,
#   'kstar': 75},
#  {'image': 'y0_72.png',
#   'image_idx': 72,
#   'mean_nll': -21.515504086178314,
#   'std_nll': 42.878941737715984,
#   'max_nll': 55.029919909183704,
#   'median_nll': -19.57653206666913,
#   'p90_nll': 35.819087873901516,
#   'top10_mean_nll': 44.02635623205171,
#   'kstar': 40},
#  {'image': 'y0_73.png',
#   'image_idx': 73,
#   'mean_nll': -37.351611711602175,
#   'std_nll': 33.402452585825365,
#   'max_nll': 43.33849691248411,
#   'median_nll': -49.52011122677374,
#   'p90_nll': 12.44968595686721,
#   'top10_mean_nll': 22.23828286678419,
#   'kstar': 12},
#  {'image': 'y0_74.png',
#   'image_idx': 74,
#   'mean_nll': -3.357440776730963,
#   'std_nll': 34.25813743503316,
#   'max_nll': 51.29494346821817,
#   'median_nll': 3.889170680205746,
#   'p90_nll': 32.81162061113252,
#   'top10_mean_nll': 38.012426363854736,
#   'kstar': 62},
#  {'image': 'y0_75.png',
#   'image_idx': 75,
#   'mean_nll': -6.927536448619443,
#   'std_nll': 33.97959906295156,
#   'max_nll': 41.0921824570596,
#   'median_nll': 2.1024494979511212,
#   'p90_nll': 31.36018665237017,
#   'top10_mean_nll': 35.4486530662375,
#   'kstar': 27},
#  {'image': 'y0_76.png',
#   'image_idx': 76,
#   'mean_nll': 18.954757433359287,
#   'std_nll': 29.26566788658183,
#   'max_nll': 71.1828103347428,
#   'median_nll': 24.58088684937342,
#   'p90_nll': 49.80942373971125,
#   'top10_mean_nll': 57.816893949618134,
#   'kstar': 100},
#  {'image': 'y0_77.png',
#   'image_idx': 77,
#   'mean_nll': -22.45180335551502,
#   'std_nll': 45.880208880907965,
#   'max_nll': 46.207601094499566,
#   'median_nll': -6.627722200001652,
#   'p90_nll': 28.627301822274912,
#   'top10_mean_nll': 34.24081907586688,
#   'kstar': 15},
#  {'image': 'y0_78.png',
#   'image_idx': 78,
#   'mean_nll': -41.81146353204818,
#   'std_nll': 41.72213636972781,
#   'max_nll': 47.2071553541858,
#   'median_nll': -60.37457585256016,
#   'p90_nll': 17.134434200961927,
#   'top10_mean_nll': 31.28960249155958,
#   'kstar': 87},
#  {'image': 'y0_79.png',
#   'image_idx': 79,
#   'mean_nll': -8.511556629871432,
#   'std_nll': 39.245085219547114,
#   'max_nll': 73.34191973400364,
#   'median_nll': -2.4807881867082124,
#   'p90_nll': 33.6537011345467,
#   'top10_mean_nll': 46.48242093414439,
#   'kstar': 40},
#  {'image': 'y0_8.png',
#   'image_idx': 8,
#   'mean_nll': -8.932763131109256,
#   'std_nll': 31.025900437240836,
#   'max_nll': 52.53711020832619,
#   'median_nll': -4.296452795739678,
#   'p90_nll': 23.967382277916883,
#   'top10_mean_nll': 35.80001859787945,
#   'kstar': 45},
#  {'image': 'y0_80.png',
#   'image_idx': 80,
#   'mean_nll': -1.5077135142496367,
#   'std_nll': 37.92685614249553,
#   'max_nll': 66.10626330342348,
#   'median_nll': 9.8426188142622,
#   'p90_nll': 41.54532224818707,
#   'top10_mean_nll': 49.98263878983717,
#   'kstar': 62},
#  {'image': 'y0_81.png',
#   'image_idx': 81,
#   'mean_nll': 19.014511927865595,
#   'std_nll': 20.686204291208647,
#   'max_nll': 65.90735124502355,
#   'median_nll': 21.390480638267913,
#   'p90_nll': 42.515804295787554,
#   'top10_mean_nll': 48.55702799325099,
#   'kstar': 75},
#  {'image': 'y0_82.png',
#   'image_idx': 82,
#   'mean_nll': -21.638054189537712,
#   'std_nll': 51.00070527393631,
#   'max_nll': 59.1285604557553,
#   'median_nll': -3.623009984700635,
#   'p90_nll': 36.7771060927766,
#   'top10_mean_nll': 43.696562907657345,
#   'kstar': 12},
#  {'image': 'y0_83.png',
#   'image_idx': 83,
#   'mean_nll': -5.1589382644364035,
#   'std_nll': 40.37630553001897,
#   'max_nll': 62.934402284939225,
#   'median_nll': 8.277345020585368,
#   'p90_nll': 38.20191803948708,
#   'top10_mean_nll': 46.81660059478629,
#   'kstar': 50},
#  {'image': 'y0_84.png',
#   'image_idx': 84,
#   'mean_nll': -7.424013833433451,
#   'std_nll': 39.246920183608324,
#   'max_nll': 66.26062543831162,
#   'median_nll': 2.4647729731736505,
#   'p90_nll': 36.436073257577895,
#   'top10_mean_nll': 44.51515939926928,
#   'kstar': 75},
#  {'image': 'y0_85.png',
#   'image_idx': 85,
#   'mean_nll': 15.091495255380329,
#   'std_nll': 31.777676791534564,
#   'max_nll': 69.5565240868951,
#   'median_nll': 22.978591672326104,
#   'p90_nll': 46.763638275181414,
#   'top10_mean_nll': 53.55042040746234,
#   'kstar': 87},
#  {'image': 'y0_86.png',
#   'image_idx': 86,
#   'mean_nll': 2.837165131118481,
#   'std_nll': 28.12580328025286,
#   'max_nll': 53.87624593571407,
#   'median_nll': 8.757360020737476,
#   'p90_nll': 33.71967177299341,
#   'top10_mean_nll': 42.739074745493475,
#   'kstar': 35},
#  {'image': 'y0_87.png',
#   'image_idx': 87,
#   'mean_nll': -20.219768942225585,
#   'std_nll': 35.31493154310622,
#   'max_nll': 44.459745695730554,
#   'median_nll': -13.905770340167484,
#   'p90_nll': 20.670510620433465,
#   'top10_mean_nll': 28.07933684803779,
#   'kstar': 25},
#  {'image': 'y0_88.png',
#   'image_idx': 88,
#   'mean_nll': 29.587688819764246,
#   'std_nll': 31.627756497366523,
#   'max_nll': 76.82256859859895,
#   'median_nll': 37.725819238718145,
#   'p90_nll': 62.93664967823767,
#   'top10_mean_nll': 70.27716418721313,
#   'kstar': 75},
#  {'image': 'y0_89.png',
#   'image_idx': 89,
#   'mean_nll': 4.246111555212986,
#   'std_nll': 31.702509538372443,
#   'max_nll': 60.616138589015705,
#   'median_nll': 11.767661209081439,
#   'p90_nll': 38.75005872500426,
#   'top10_mean_nll': 46.4688648983223,
#   'kstar': 62},
#  {'image': 'y0_9.png',
#   'image_idx': 9,
#   'mean_nll': 7.395478898608415,
#   'std_nll': 25.684384283265015,
#   'max_nll': 63.23628011749085,
#   'median_nll': 13.16285357812297,
#   'p90_nll': 33.45204698348037,
#   'top10_mean_nll': 41.52748568942741,
#   'kstar': 35},
#  {'image': 'y0_90.png',
#   'image_idx': 90,
#   'mean_nll': -35.960305034937804,
#   'std_nll': 30.617257471093648,
#   'max_nll': 71.02240605764172,
#   'median_nll': -35.57790612271431,
#   'p90_nll': -0.4984762422827829,
#   'top10_mean_nll': 25.499103382684396,
#   'kstar': 50},
#  {'image': 'y0_91.png',
#   'image_idx': 91,
#   'mean_nll': -12.419516333258516,
#   'std_nll': 36.485524509824174,
#   'max_nll': 54.79004292799252,
#   'median_nll': -11.258724105232204,
#   'p90_nll': 37.78552741213805,
#   'top10_mean_nll': 45.80780316652395,
#   'kstar': 15},
#  {'image': 'y0_92.png',
#   'image_idx': 92,
#   'mean_nll': -17.996328775743123,
#   'std_nll': 37.95081054785651,
#   'max_nll': 65.50263682512775,
#   'median_nll': -14.475224885366549,
#   'p90_nll': 31.033713739502918,
#   'top10_mean_nll': 42.420485418477085,
#   'kstar': 87},
#  {'image': 'y0_93.png',
#   'image_idx': 93,
#   'mean_nll': -11.989004223836227,
#   'std_nll': 30.453914875630876,
#   'max_nll': 50.57954658975568,
#   'median_nll': -8.380026572557767,
#   'p90_nll': 23.193570235125296,
#   'top10_mean_nll': 31.676774611396397,
#   'kstar': 17},
#  {'image': 'y0_94.png',
#   'image_idx': 94,
#   'mean_nll': -11.713574597485918,
#   'std_nll': 21.56735270410983,
#   'max_nll': 55.77926295492913,
#   'median_nll': -11.090742119217227,
#   'p90_nll': 14.591135545695142,
#   'top10_mean_nll': 25.390771180661943,
#   'kstar': 45},
#  {'image': 'y0_95.png',
#   'image_idx': 95,
#   'mean_nll': 15.35925930613875,
#   'std_nll': 28.575470563670038,
#   'max_nll': 60.420132276657576,
#   'median_nll': 23.61796020070862,
#   'p90_nll': 42.406777936822586,
#   'top10_mean_nll': 49.38967539087921,
#   'kstar': 75},
#  {'image': 'y0_96.png',
#   'image_idx': 96,
#   'mean_nll': -7.095951803625863,
#   'std_nll': 39.60310401672578,
#   'max_nll': 61.17465890730497,
#   'median_nll': 7.6512928966687035,
#   'p90_nll': 32.85893958401863,
#   'top10_mean_nll': 42.00702418263625,
#   'kstar': 100},
#  {'image': 'y0_97.png',
#   'image_idx': 97,
#   'mean_nll': -2.0949389962280516,
#   'std_nll': 31.508325632785358,
#   'max_nll': 64.60254493200529,
#   'median_nll': 5.066886447649825,
#   'p90_nll': 33.64636240928153,
#   'top10_mean_nll': 46.01226061114594,
#   'kstar': 12},
#  {'image': 'y0_98.png',
#   'image_idx': 98,
#   'mean_nll': -11.876640346154103,
#   'std_nll': 30.585351022693374,
#   'max_nll': 51.14850208397616,
#   'median_nll': -6.073644881910785,
#   'p90_nll': 22.662822878619412,
#   'top10_mean_nll': 28.98763563474464,
#   'kstar': 25},
#  {'image': 'y0_99.png',
#   'image_idx': 99,
#   'mean_nll': 0.18860956714078586,
#   'std_nll': 32.90306583168166,
#   'max_nll': 62.54551684229499,
#   'median_nll': 1.7830239531294558,
#   'p90_nll': 42.244273401485934,
#   'top10_mean_nll': 49.72591696838121,
#   'kstar': 75}]

# %%
import pandas as pd

df = pd.DataFrame(rows).sort_values("image").reset_index(drop=True)
df.to_csv("gmm_results_imgnet100_noise.csv", index=False)
print("saved gmm_results_imgnet100_noise.csv")
df
# Out:
# saved gmm_results_imgnet100_noise.csv
#         image  image_idx   mean_nll    std_nll    max_nll  median_nll  \
# 0    y0_0.png          0 -39.746578  32.338275  38.199199  -38.453370
# 1    y0_1.png          1  -6.047211  35.588335  50.648748   -1.565227
# 2   y0_10.png         10 -12.751328  24.403116  60.455306  -14.614785
# 3   y0_11.png         11  -1.267631  24.833926  48.901896    3.431427
# 4   y0_12.png         12   2.498776  25.283477  50.786066    4.420963
# ..        ...        ...        ...        ...        ...         ...
# 95  y0_95.png         95  15.359259  28.575471  60.420132   23.617960
# 96  y0_96.png         96  -7.095952  39.603104  61.174659    7.651293
# 97  y0_97.png         97  -2.094939  31.508326  64.602545    5.066886
# 98  y0_98.png         98 -11.876640  30.585351  51.148502   -6.073645
# 99  y0_99.png         99   0.188610  32.903066  62.545517    1.783024
#
#       p90_nll  top10_mean_nll  kstar
# 0    1.846786       15.730550     27
# 1   38.556591       44.692743     45
# 2   16.557806       36.097977     35
# 3   24.105337       33.212227     62
# 4   33.879755       41.131846      8
# ..        ...             ...    ...
# 95  42.406778       49.389675     75
# 96  32.858940       42.007024    100
# 97  33.646362       46.012261     12
# 98  22.662823       28.987636     25
# 99  42.244273       49.725917     75
#
# [100 rows x 9 columns]

# %%
from scipy.stats import pearsonr, spearmanr

features = ["mean_nll", "std_nll", "max_nll", "median_nll", "p90_nll", "top10_mean_nll"]

for feat in features:
    x = df[feat].values
    y = df["kstar"].values

    pearson_r, pearson_p = pearsonr(x, y)
    spearman_r, spearman_p = spearmanr(x, y)

    print(f"{feat} vs k*")
    print(f"  Pearson:  r={pearson_r:.4f}, p={pearson_p:.4f}")
    print(f"  Spearman: r={spearman_r:.4f}, p={spearman_p:.4f}")
    print()
# Out:
# mean_nll vs k*
#   Pearson:  r=0.3613, p=0.0002
#   Spearman: r=0.3721, p=0.0001
#
# std_nll vs k*
#   Pearson:  r=-0.0896, p=0.3754
#   Spearman: r=-0.0409, p=0.6864
#
# max_nll vs k*
#   Pearson:  r=0.2451, p=0.0140
#   Spearman: r=0.2440, p=0.0144
#
# median_nll vs k*
#   Pearson:  r=0.3235, p=0.0010
#   Spearman: r=0.3797, p=0.0001
#
# p90_nll vs k*
#   Pearson:  r=0.3244, p=0.0010
#   Spearman: r=0.2873, p=0.0037
#
# top10_mean_nll vs k*
#   Pearson:  r=0.3082, p=0.0018
#   Spearman: r=0.2817, p=0.0045

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

features = ["mean_nll", "std_nll", "max_nll", "median_nll", "p90_nll", "top10_mean_nll"]

rows = []

for feat in features:
    x = df[feat].values
    y = df["kstar"].values

    pearson_r, pearson_p = pearsonr(x, y)
    spearman_r, spearman_p = spearmanr(x, y)

    rows.append({
        "feature": feat,
        "pearson_r": pearson_r,
        "pearson_p": pearson_p,
        "spearman_r": spearman_r,
        "spearman_p": spearman_p
    })

corr_df = pd.DataFrame(rows)
corr_df
# Out:
#           feature  pearson_r  pearson_p  spearman_r  spearman_p
# 0        mean_nll   0.361345   0.000221    0.372086    0.000138
# 1         std_nll  -0.089583   0.375427   -0.040867    0.686431
# 2         max_nll   0.245093   0.013982    0.244024    0.014418
# 3      median_nll   0.323529   0.001026    0.379720    0.000098
# 4         p90_nll   0.324354   0.000994    0.287329    0.003749
# 5  top10_mean_nll   0.308174   0.001813    0.281658    0.004527
